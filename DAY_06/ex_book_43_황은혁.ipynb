# %% [markdown]
# ##### pandas를 이용한 파이썬 데이터 분석 기초

# %%
import pandas as pd
import df_util as util

# %%
import numpy as np

# %%
df =pd.read_csv(r'C:\Users\a\Desktop\EX_PANDAS\DAY_06\train_bikes.csv')

# %%
df.head(3)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32

# %%
df.iloc[2,3] =np.nan

# %%
# 결측치 한개 생성후 발견
df.isna().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    1
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
util.checkDataFrame(df,df)
# Out:
# [                  datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0         0.0        1   9.84
# 1      2011-01-01 01:00:00       1        0         0.0        1   9.02
# 2      2011-01-01 02:00:00       1        0         NaN        1   9.02
# 3      2011-01-01 03:00:00       1        0         0.0        1   9.84
# 4      2011-01-01 04:00:00       1        0         0.0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0         1.0        1  15.58
# 10882  2012-12-19 20:00:00       4        0         1.0        1  14.76
# 10883  2012-12-19 21:00:00       4        0         1.0        1  13.94
# 10884  2012-12-19 22:00:00       4        0         1.0        1  13.94
# 10885  2012-12-19 23:00:00       4        0         1.0        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df =pd.read_csv(r'C:\Users\a\Desktop\EX_PANDAS\DAY_06\train_bikes.csv')

# %%
df.iloc[2:5,3:6]
# Out:
#    workingday  weather  temp
# 2           0        1  9.02
# 3           0        1  9.84
# 4           0        1  9.84

# %%
df.loc[2:4,'workingday':'temp']
# Out:
#    workingday  weather  temp
# 2           0        1  9.02
# 3           0        1  9.84
# 4           0        1  9.84

# %%
df['season'] == 2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10881    False
# 10882    False
# 10883    False
# 10884    False
# 10885    False
# Name: season, Length: 10886, dtype: bool

# %%
df.loc[df['season'] == 2]
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 1323  2011-04-01 00:00:00       2        0           1        3  10.66
# 1324  2011-04-01 01:00:00       2        0           1        3  10.66
# 1325  2011-04-01 02:00:00       2        0           1        3  10.66
# 1326  2011-04-01 03:00:00       2        0           1        2   9.84
# 1327  2011-04-01 04:00:00       2        0           1        2   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 8146  2012-06-19 19:00:00       2        0           1        1  32.80
# 8147  2012-06-19 20:00:00       2        0           1        1  32.80
# 8148  2012-06-19 21:00:00       2        0           1        1  31.16
# 8149  2012-06-19 22:00:00       2        0           1        1  29.52
# 8150  2012-06-19 23:00:00       2        0           1        1  29.52
#
#        atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.loc[df['season'] == 2,'casual':'count']
# Out:
#       casual  registered  count
# 1323       0           6      6
# 1324       0           4      4
# 1325       0           7      7
# 1326       0           4      4
# 1327       0           3      3
# ...      ...         ...    ...
# 8146      82         432    514
# 8147      59         399    458
# 8148      37         239    276
# 8149      51         240    291
# 8150      23         102    125
#
# [2733 rows x 3 columns]

# %%
df.loc[df['season'] == 2,'casual':]
# Out:
#       casual  registered  count
# 1323       0           6      6
# 1324       0           4      4
# 1325       0           7      7
# 1326       0           4      4
# 1327       0           3      3
# ...      ...         ...    ...
# 8146      82         432    514
# 8147      59         399    458
# 8148      37         239    276
# 8149      51         240    291
# 8150      23         102    125
#
# [2733 rows x 3 columns]

# %%
df.loc[(df['season'] != 1) & (df['weather'] != 2)]
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 1323   2011-04-01 00:00:00       2        0           1        3  10.66
# 1324   2011-04-01 01:00:00       2        0           1        3  10.66
# 1325   2011-04-01 02:00:00       2        0           1        3  10.66
# 1328   2011-04-01 05:00:00       2        0           1        3   9.84
# 1329   2011-04-01 06:00:00       2        0           1        3   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.loc[~(df['season'] == 1) & ~(df['weather'] == 2)]
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 1323   2011-04-01 00:00:00       2        0           1        3  10.66
# 1324   2011-04-01 01:00:00       2        0           1        3  10.66
# 1325   2011-04-01 02:00:00       2        0           1        3  10.66
# 1328   2011-04-01 05:00:00       2        0           1        3   9.84
# 1329   2011-04-01 06:00:00       2        0           1        3   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df.select_dtypes(include = 'int')
# Out:
#        season  holiday  workingday  weather  humidity  casual  registered  \
# 0           1        0           0        1        81       3          13
# 1           1        0           0        1        80       8          32
# 2           1        0           0        1        80       5          27
# 3           1        0           0        1        75       3          10
# 4           1        0           0        1        75       0           1
# ...       ...      ...         ...      ...       ...     ...         ...
# 10881       4        0           1        1        50       7         329
# 10882       4        0           1        1        57      10         231
# 10883       4        0           1        1        61       4         164
# 10884       4        0           1        1        61      12         117
# 10885       4        0           1        1        66       4          84
#
#        count
# 0         16
# 1         40
# 2         32
# 3         13
# ...

# %%
df.select_dtypes(exclude = 'int')
# Out:
#                   datetime   temp   atemp  windspeed
# 0      2011-01-01 00:00:00   9.84  14.395     0.0000
# 1      2011-01-01 01:00:00   9.02  13.635     0.0000
# 2      2011-01-01 02:00:00   9.02  13.635     0.0000
# 3      2011-01-01 03:00:00   9.84  14.395     0.0000
# 4      2011-01-01 04:00:00   9.84  14.395     0.0000
# ...                    ...    ...     ...        ...
# 10881  2012-12-19 19:00:00  15.58  19.695    26.0027
# 10882  2012-12-19 20:00:00  14.76  17.425    15.0013
# 10883  2012-12-19 21:00:00  13.94  15.910    15.0013
# 10884  2012-12-19 22:00:00  13.94  17.425     6.0032
# 10885  2012-12-19 23:00:00  13.12  16.665     8.9981
#
# [10886 rows x 4 columns]

# %%
df =pd.read_csv(r'C:\Users\a\Desktop\EX_PANDAS\DAY_06\train_bikes.csv')

# %%
df = df.set_index('datetime')

# %%
df
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-19 19:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 20:00:00       4        0           1        1  14.76  17.425
# 2012-12-19 21:00:00       4        0           1        1  13.94  15.910
# 2012-12-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-12-19 23:00:00       4        0           1        1  13.12  16.665
#
#                      humidity  windspeed  casual  registered  count
# datetime
# ...

# %%
df.filter(items = ['humidity','windspeed'])
# Out:
#                      humidity  windspeed
# datetime
# 2011-01-01 00:00:00        81     0.0000
# 2011-01-01 01:00:00        80     0.0000
# 2011-01-01 02:00:00        80     0.0000
# 2011-01-01 03:00:00        75     0.0000
# 2011-01-01 04:00:00        75     0.0000
# ...                       ...        ...
# 2012-12-19 19:00:00        50    26.0027
# 2012-12-19 20:00:00        57    15.0013
# 2012-12-19 21:00:00        61    15.0013
# 2012-12-19 22:00:00        61     6.0032
# 2012-12-19 23:00:00        66     8.9981
#
# [10886 rows x 2 columns]

# %%
df.filter(regex='in.s')
# Out:
#                      windspeed
# datetime
# 2011-01-01 00:00:00     0.0000
# 2011-01-01 01:00:00     0.0000
# 2011-01-01 02:00:00     0.0000
# 2011-01-01 03:00:00     0.0000
# 2011-01-01 04:00:00     0.0000
# ...                        ...
# 2012-12-19 19:00:00    26.0027
# 2012-12-19 20:00:00    15.0013
# 2012-12-19 21:00:00    15.0013
# 2012-12-19 22:00:00     6.0032
# 2012-12-19 23:00:00     8.9981
#
# [10886 rows x 1 columns]

# %%
df.rename({'registered':'registered_user','casual':'unregistered_user'},axis=1)
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-19 19:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 20:00:00       4        0           1        1  14.76  17.425
# 2012-12-19 21:00:00       4        0           1        1  13.94  15.910
# 2012-12-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-12-19 23:00:00       4        0           1        1  13.12  16.665
#
#                      humidity  windspeed  unregistered_user  registered_user  \
# ...

# %%
df.rename(columns={'registered':'registered_user','casual':'unregistered_user'})
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-19 19:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 20:00:00       4        0           1        1  14.76  17.425
# 2012-12-19 21:00:00       4        0           1        1  13.94  15.910
# 2012-12-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-12-19 23:00:00       4        0           1        1  13.12  16.665
#
#                      humidity  windspeed  unregistered_user  registered_user  \
# ...

# %%
df.pd.read_csv('./datasets/bookings/bookings.csv')

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-19 19:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 20:00:00       4        0           1        1  14.76  17.425
# 2012-12-19 21:00:00       4        0           1        1  13.94  15.910
# 2012-12-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-12-19 23:00:00       4        0           1        1  13.12  16.665
#
# ...

# %%
df.describe(include='subject')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.describe(include='subject')
#
# File c:\Users\a\anaconda3\envs\py_39\lib\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# ...

# %%
df['workingday'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of datetime
# 2011-01-01 00:00:00    0
# 2011-01-01 01:00:00    0
# 2011-01-01 02:00:00    0
# 2011-01-01 03:00:00    0
# 2011-01-01 04:00:00    0
#                       ..
# 2012-12-19 19:00:00    1
# 2012-12-19 20:00:00    1
# 2012-12-19 21:00:00    1
# 2012-12-19 22:00:00    1
# 2012-12-19 23:00:00    1
# Name: workingday, Length: 10886, dtype: int64>
